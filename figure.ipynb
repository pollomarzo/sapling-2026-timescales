# %%
#| label: fig-tau
#| caption: Intrinsic timescale recovered from each region's autocorrelation, against hierarchical level. Points are the across-seed mean; the band is one standard deviation.

import altair as alt
import pandas as pd

df = pd.DataFrame({
    'level': range(1, 9),
    'tau':  [3, 5, 8, 12, 17, 24, 32, 40],
    'lo':   [2.2, 4.0, 6.8, 10.5, 15.0, 21.5, 29.0, 36.5],
    'hi':   [3.8, 6.0, 9.2, 13.5, 19.0, 26.5, 35.0, 43.5],
})

band = alt.Chart(df).mark_area(opacity=0.15, color='#2f6b4f').encode(
    x=alt.X('level:Q', title='Hierarchical level'),
    y=alt.Y('lo:Q', title='Intrinsic timescale (steps)'), y2='hi:Q')
line = alt.Chart(df).mark_line(color='#2f6b4f', strokeWidth=2.5).encode(x='level:Q', y='tau:Q')
points = alt.Chart(df).mark_point(color='#2f6b4f', filled=True, size=70).encode(
    x='level:Q', y='tau:Q', tooltip=['level', 'tau', 'lo', 'hi'])

(band + line + points).properties(width=460, height=280)
# Out:
# <div id="fig-tau-viz" style="width:100%;max-width:560px;margin:0 auto"></div>
# <script src="https://cdn.jsdelivr.net/npm/vega@5"></script>
# <script src="https://cdn.jsdelivr.net/npm/vega-lite@5"></script>
# <script src="https://cdn.jsdelivr.net/npm/vega-embed@6"></script>
# <script>vegaEmbed("#fig-tau-viz", {"$schema":"https://vega.github.io/schema/vega-lite/v5.json","description":"Intrinsic timescale against hierarchical level.","width":460,"height":280,"data":{"values":[{"level":1,"tau":3,"lo":2.2,"hi":3.8},{"level":2,"tau":5,"lo":4,"hi":6},{"level":3,"tau":8,"lo":6.8,"hi":9.2},{"level":4,"tau":12,"lo":10.5,"hi":13.5},{"level":5,"tau":17,"lo":15,"hi":19},{"level":6,"tau":24,"lo":21.5,"hi":26.5},{"level":7,"tau":32,"lo":29,"hi":35},{"level":8,"tau":40,"lo":36.5,"hi":43.5}]},"encoding":{"x":{"field":"level","type":"quantitative","title":"Hierarchical level","axis":{"tickCount":8,"grid":false},"scale":{"domain":[0.5,8.5]}}},"layer":[{"mark":{"type":"area","opacity":0.15,"color":"#2f6b4f"},"encoding":{"y":{"field":"lo","type":"quantitative","title":"Intrinsic timescale (steps)"},"y2":{"field":"hi"}}},{"mark":{"type":"line","color":"#2f6b4f","strokeWidth":2.5},"encoding":{"y":{"field":"tau","type":"quantitative"}}},{"mark":{"type":"point","color":"#2f6b4f","filled":true,"size":70},"encoding":{"y":{"field":"tau","type":"quantitative"},"tooltip":[{"field":"level","title":"Level"},{"field":"tau","title":"Timescale"},{"field":"lo","title":"-1 SD"},{"field":"hi","title":"+1 SD"}]}}]}, {actions:false}).catch(console.error);</script>
